# %% [markdown]
# # TASK 3

# %%
import pandas as pd

# %%
shivansh_cv = pd.read_csv("/content/shivansh_cv.csv")
jaya_cv = pd.read_csv("/content/jaya_cv.csv")
outsider_cv = pd.read_csv('/content/outsider.csv')

# %%
shivansh_cv.head(5)
# Out:
#    annotation_id  annotator                   created_at     id  \
# 0             22          1  2025-01-27T16:08:23.075193Z  14420
# 1             23          1  2025-01-27T16:08:33.435552Z  14421
# 2             24          1  2025-01-27T16:08:43.000499Z  14422
# 3             25          1  2025-01-27T16:08:49.387909Z  14423
# 4             26          1  2025-01-27T16:10:37.459903Z  14424
#
#                                  image  lead_time        tag  \
# 0  /data/upload/2/4efef24b-img_740.jpg      6.425  No Trucks
# 1  /data/upload/2/638eddcd-img_741.jpg      7.927     Trucks
# 2  /data/upload/2/3b3fa8ab-img_742.jpg      4.550     Trucks
# 3  /data/upload/2/f48ee300-img_743.jpg      4.159     Trucks
# 4  /data/upload/2/a503d975-img_744.jpg    114.151     Trucks
#
#                     updated_at
# 0  2025-01-27T16:08:23.075222Z
# 1  2025-01-27T16:08:33.435578Z
# 2  2025-01-27T16:08:43.000525Z
# 3  2025-01-27T16:08:49.388048Z
# 4  2025-01-27T16:12:25.178045Z

# %%
jaya_cv.head(5)
# Out:
#    annotation_id  annotator                   created_at     id  \
# 0             44          1  2025-01-27T16:44:12.533810Z  14422
# 1             45          1  2025-01-27T16:44:25.843131Z  14423
# 2             46          1  2025-01-27T16:44:38.621000Z  14424
# 3             47          1  2025-01-27T16:44:49.591158Z  14425
# 4             48          1  2025-01-27T16:45:00.936278Z  14426
#
#                                  image      label  lead_time  \
# 0  /data/upload/3/9fa8005f-img_740.jpg  No Trucks      7.518
# 1  /data/upload/3/50484c46-img_741.jpg     Trucks      6.630
# 2  /data/upload/3/497510af-img_742.jpg     Trucks      8.924
# 3  /data/upload/3/6eec6886-img_744.jpg     Trucks      6.794
# 4  /data/upload/3/d4660c2e-img_745.jpg     Trucks      8.763
#
#                     updated_at
# 0  2025-01-27T16:44:12.533859Z
# 1  2025-01-27T16:44:25.843157Z
# 2  2025-01-27T16:44:38.621044Z
# 3  2025-01-27T16:44:49.591197Z
# 4  2025-01-27T16:45:00.936308Z

# %%
len(jaya_cv)
# Out:
# 20

# %%
len(shivansh_cv)
# Out:
# 20

# %% [markdown]
# ##

# %% [markdown]
# ### FLIESS KAPPA CALCULATION FOR THE CV DATASET

# %%
import pandas as pd
from statsmodels.stats.inter_rater import fleiss_kappa

# Extract the three choice columns
choice_column_1 = shivansh_cv["tag"]
choice_column_2 = jaya_cv["label"]

# orgnizing the data into a rating matrix
# Assuming categories are integers or labels and creating the rating matrix

categories = sorted(set(choice_column_1) | set(choice_column_2) | set(choice_column_3))
rating_matrix = []

for i in range(len(choice_column_1)):
  row = [0]* len(categories)
  row[categories.index(choice_column_1[i])] += 1
  row[categories.index(choice_column_2[i])] += 1
  rating_matrix.append(row)

# Convert to DataFrame for clarity
rating_df = pd.DataFrame(rating_matrix, columns=categories)

# Calculate Fleiss' Kappa
kappa = fleiss_kappa(rating_df.values, method='fleiss')
print(f"Fleiss' Kappa: {kappa}")
# Out:
# Fleiss' Kappa: 0.3406593406593405

# %%
import pandas as pd
from statsmodels.stats.inter_rater import fleiss_kappa

# Extract the three choice columns
choice_column_1 = shivansh_cv["tag"]
choice_column_2 = jaya_cv["label"]
choice_column_3 = outsider_cv["tag"]

# orgnizing the data into a rating matrix
# Assuming categories are integers or labels and creating the rating matrix

categories = sorted(set(choice_column_1) | set(choice_column_2) | set(choice_column_3))
rating_matrix = []

for i in range(len(choice_column_1)):
  row = [0]* len(categories)
  row[categories.index(choice_column_1[i])] += 1
  row[categories.index(choice_column_2[i])] += 1
  row[categories.index(choice_column_3[i])] += 1
  rating_matrix.append(row)

# Convert to DataFrame for clarity
rating_df = pd.DataFrame(rating_matrix, columns=categories)

# Calculate Fleiss' Kappa
kappa = fleiss_kappa(rating_df.values, method='fleiss')
print(f"Fleiss' Kappa: {kappa}")
# Out:
# Fleiss' Kappa: 0.55

# %% [markdown]
# ## COHEN'S KAPPA CALCULATION

# %%
shivansh_nlp = pd.read_csv("/content/shivansh_nlp.csv")
jaya_nlp = pd.read_csv("/content/jaya_nlp.csv")

# %%
shivansh_nlp.head(5)
# Out:
#    annotation_id  annotator                   created_at   id  lead_time  \
# 0              1          1  2025-01-26T18:05:05.754370Z  740   3239.558
# 1              2          1  2025-01-27T05:44:04.080498Z  741    538.029
# 2              3          1  2025-01-27T05:53:49.380340Z  742    581.726
# 3              4          1  2025-01-27T05:58:12.771521Z  743    259.863
# 4              5          1  2025-01-27T06:02:01.746220Z  744    222.087
#
#                                                  ner  \
# 0  [{"start":0,"end":2,"text":"हम","labels":["PRO...
# 1  [{"start":0,"end":3,"text":"EVM","labels":["NO...
# 2  [{"start":0,"end":3,"text":"मैं","labels":["PR...
# 3  [{"start":0,"end":4,"text":"मुझे","labels":["P...
# 4  [{"start":0,"end":11,"text":"Mallikarjun","lab...
#
#                                                 text  \
# 0  हम डरते नहीं है, 15 साल की सरकार 15 सीटों पर स...
# 1  EVM पर कोई भी बटन दबाइए, वोट BJP को ही जाएगा’-...
# 2  मैं ना मरने से डरता ना जेल जाने से' BJP पर भड़...
# 3  मुझे ये बताते हुए खुशी हो रही है कि'...| Sonia...
# 4  Mallikarjun Kharge ने BJP के झूठ का पुलिंदा खो...
#
#                     updated_at
# 0  2025-01-26T18:05:56.750206Z
# 1  2025-01-27T05:44:04.080559Z
# 2  2025-01-27T05:53:49.380377Z
# 3  2025-01-27T05:58:12.771563Z
# 4  2025-01-27T06:02:01.746260Z

# %%
jaya_nlp.head(5)
# Out:
#    annotation_id  annotator                   created_at   id  lead_time  \
# 0             25          1  2025-01-27T01:58:52.248324Z   22  27892.774
# 1              1          1  2025-01-26T17:44:57.383261Z  740    298.956
# 2              2          1  2025-01-26T18:01:28.385664Z  741    690.818
# 3              3          1  2025-01-26T18:11:52.660376Z  742    305.925
# 4             26          1  2025-01-27T02:02:12.871171Z  743    145.131
#
#                                                  ner  \
# 0  [{"start":0,"end":10,"text":"#Jalandhar","labe...
# 1  [{"start":0,"end":16,"text":"Himachal Pradesh"...
# 2  [{"start":17,"end":19,"text":"15","labels":["N...
# 3  [{"start":84,"end":92,"text":"D Arvind","label...
# 4  [{"start":0,"end":3,"text":"मैं","labels":["PR...
#
#                                                 text  \
# 0  #Jalandhar के लोगों कोKejriwal की गारंटी | #ar...
# 1  Himachal Pradesh को मदद की जरूरत है... | CM Su...
# 2  हम डरते नहीं है, 15 साल की सरकार 15 सीटों पर स...
# 3  EVM पर कोई भी बटन दबाइए, वोट BJP को ही जाएगा’-...
# 4  मैं ना मरने से डरता ना जेल जाने से' BJP पर भड़...
#
#                     updated_at
# 0  2025-01-27T01:58:52.248367Z
# 1  2025-01-26T17:50:21.594517Z
# 2  2025-01-26T18:01:28.385706Z
# 3  2025-01-26T18:11:52.660411Z
# 4  2025-01-27T02:02:12.871213Z

# %%
len(shivansh_nlp)
# Out:
# 21

# %%
len(jaya_nlp)
# Out:
# 22

# %%
print(shivansh_nlp['ner'][5])
# Out:
# [{"start":0,"end":6,"text":"गुजरात","labels":["PROPN"]},{"start":46,"end":54,"text":"Kanhaiya","labels":["PROPN"]},{"start":55,"end":60,"text":"Kumar","labels":["PROPN"]},{"start":69,"end":72,"text":"BJP","labels":["PROPN"]},{"start":61,"end":63,"text":"ने","labels":["ADP"]},{"start":73,"end":75,"text":"की","labels":["ADP"]},{"start":32,"end":34,"text":"को","labels":["ADP"]},{"start":40,"end":43,"text":"करो","labels":["VERB"]},{"start":43,"end":44,"text":"'","labels":["X"]},{"start":44,"end":45,"text":"-","labels":["X"]},{"start":7,"end":9,"text":"से","labels":["ADP"]},{"start":10,"end":13,"text":"आया","labels":["VERB"]},{"start":35,"end":39,"text":"सलाम","labels":["NOUN"]},{"start":76,"end":79,"text":"पोल","labels":["NOUN"]},{"start":64,"end":68,"text":"खोली","labels":["VERB"]},{"start":14,"end":19,"text":"मेरा ","labels":["PRON"]},{"start":19,"end":24,"text":"दोस्त","labels":["NOUN"]},{"start":26,"end":31,"text":"दोस्त","labels":["NOUN"]},{"start":24,"end":25,"text":",","labels":["X"]}]
